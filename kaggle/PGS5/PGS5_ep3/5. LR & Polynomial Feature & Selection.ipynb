# %%
import pandas as pd
import numpy as np
import polars as pl
import sgml, sgutil, sgpp
import joblib
from sklearn.feature_selection import SequentialFeatureSelector

from sklearn.pipeline import make_pipeline
sc = sgutil.SGCache('img', 'result', 'model')
data_processor = joblib.load('model/data_processor.joblib')
data_processor_org = joblib.load('model/data_processor_org.joblib')
df_train = data_processor.transform(['data/train.csv'])
df_org = data_processor_org.transform(['data/Rainfall.csv'])
target = 'rainfall'

# %%
df_train.columns
# Out:
# Index(['day', 'rainfall', 'sin_ed', 'pressure', 'maxtemp', 'temparature',
#        'mintemp', 'dewpoint', 'humidity', 'cloud', 'sunshine', 'windspeed',
#        'cos_wd', 'sin_wd', 'chp', 'sunshine_1', 'sunshine_2', 'sunshine_3',
#        'sunshine_4', 'sunshine_5', 'sunshine_6', 'cloud_1', 'cloud_2',
#        'cloud_3', 'cloud_4', 'cloud_5', 'cloud_6', 'dewpoint_1', 'dewpoint_2',
#        'dewpoint_3', 'dewpoint_4', 'dewpoint_5', 'dewpoint_6', 'chp_1',
#        'chp_2', 'chp_3', 'chp_4', 'chp_5', 'chp_6', 'cos_wd_1', 'cos_wd_2',
#        'cos_wd_3', 'cos_wd_4', 'cos_wd_5', 'cos_wd_6', 'sin_wd_1', 'sin_wd_2',
#        'sin_wd_3', 'sin_wd_4', 'sin_wd_5', 'sin_wd_6', 'pressure_ma24',
#        'maxtemp_ma24', 'temparature_ma24', 'mintemp_ma24', 'dewpoint_ma24',
#        'humidity_ma24', 'cloud_ma24', 'sunshine_ma24', 'windspeed_ma24',
#        'cos_wd_ma24', 'sin_wd_ma24', 'chp_ma24', 'year', 'expected_day',
#        'winddirection'],
#       dtype='object')

# %%
df_train[['pressure', 'temparature', 'dewpoint', 'humidity', 'cloud', 'sunshine', 'windspeed']]
# Out:
#       rainfall  pressure  temparature  dewpoint  humidity     cloud  sunshine  \
# id
# 0            1  0.680597    -0.641047 -0.198771  0.615466  0.673271 -0.723282
# 1            1  1.054482    -1.347884 -0.951720  1.640146  0.839943 -1.026438
# 2            1  1.873474    -1.500714 -2.099967 -0.921554 -1.604580  1.261016
# 3            1 -0.031574    -1.175951 -0.688188  1.640146  1.062173 -1.026438
# 4            0  1.463978    -1.061329 -2.043495 -3.867510 -1.715695 -0.034289
# ...        ...       ...          ...       ...       ...       ...       ...
# 2185         1  0.182068    -0.641047 -0.104652  1.896316  0.673271 -0.998878
# 2186         1 -0.209617    -1.271470 -0.970543  1.127806  0.673271 -1.026438
# 2187         1 -0.049385    -1.462507 -1.478784 -0.409214  0.173255  0.351547
# 2188         1  1.552999    -1.672647 -1.083486  1.255891  0.951058 -0.998878
# 2189         1  0.039636    -0.927603 -0.462303  0.871636  0.673271 -0.750841
#
#       windspeed
# id
# 0     -0.481616
# 1     -0.007524
# 2     -0.390832
# 3      1.374405
# 4      0.285001
# ...         ...
# 2185   0.012650
# 2186   1.344143
# 2187   1.102054
# 2188  -0.400920
# 2189   2.625201
#
# [2190 rows x 8 columns]

# %%
data_proc_2 = make_pipeline(data_processor[0], data_processor[1])
data_proc_2 =
# Out:
# Pipeline(steps=[('pipeline-1',
#                  Pipeline(steps=[('polarsprocessor',
#                                   <sgpp.PolarsProcessor object at 0x7f2e97829100>),
#                                  ('exprprocessor-1',
#                                   <sgpp.ExprProcessor object at 0x7f2e97931700>),
#                                  ('exprprocessor-2',
#                                   <sgpp.ExprProcessor object at 0x7f2e8dc75730>)])),
#                 ('pipeline-2',
#                  Pipeline(steps=[('exprprocessor',
#                                   <sgpp.ExprProcessor object at 0x7f2e8dc75a60>),
#                                  ('pandascoverter',
#                                   <sgpp.PandasCoverter object at 0x7f2e8dc76870>)]))])
