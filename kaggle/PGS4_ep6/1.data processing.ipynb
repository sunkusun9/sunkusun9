# %%
import pandas as pd
import numpy as np
import polars as pl
import polars.selectors as cs
import sys, os, re
import pickle as pkl
import dproc
from functools import partial

print(sys.version)

for i in [pd, pl, np]:
    print(i.__name__, i.__version__)
# Out:
# 3.12.3 (main, May  7 2024, 08:28:12) [GCC 9.4.0]
# pandas 2.2.2
# polars 0.20.24
# numpy 1.26.4

# %% [markdown]
# ## 다운로드

# %%
data_path = 'data'
if not os.path.isdir(data_path):
    os.mkdir(data_path)
files = {
    k: os.path.join(p, f)
    for k, p, f in [
        ('train', data_path, 'train.csv'),
        ('test', data_path, 'test.csv'),
        ('org', data_path, 'data.csv'),
        ('train_pkl', data_path, 'train.pkl'),
        ('org_pkl', data_path, 'org.pkl'),
        ('test_pkl', data_path, 'test.pkl'),
        ('var_pkl', data_path, 'var.pkl')
    ]
}

if not os.path.isfile(files['train']):
    # !kaggle competitions download -c playground-series-s4e6
    # !unzip playground-series-s4e6.zip -d data
    # !rm playground-series-s4e6.zip
    # !wget https://archive.ics.uci.edu/static/public/697/predict+students+dropout+and+academic+success.zip
    # !unzip predict+students+dropout+and+academic+success.zip -d data
    # !rm predict+students+dropout+and+academic+success.zip

# %% [markdown]
# ## 변수 정보 수집 및 변수 타입 선정

# %%
# UCI Repository에서 수집한 변수 정보를 variable.tsv에 저장해두었습니다.
# 이를 불러옵니다.
df_var = pd.read_csv('variables.tsv', sep='\t')\
    .drop(columns=['Units', 'Missing Values'])\
    .rename(columns={'Variable Name': 'name'})\
    .set_index('name')

# %%
# 변수의 타입을 정하기 위한 정보를 수집해와서 변수의 타입을 정합니다.
df_type = dproc.merge_type_df([
    pl.scan_csv(files['train']).pipe(dproc.get_type_df).pipe(lambda x: x.set_index(x.index.map(lambda x: x.strip()))),
    pl.scan_csv(files['test']).pipe(dproc.get_type_df).pipe(lambda x: x.set_index(x.index.map(lambda x: x.strip()))),
    pl.scan_csv(files['org'], separator=';').pipe(dproc.get_type_df).pipe(lambda x: x.set_index(x.index.map(lambda x: x.strip())))
])
X_cat= ['Marital status', 'Application mode', 'Course', 'Nacionality', "Mother's occupation", "Father's occupation"]
dt = dproc.get_type_pl(
    df_type
)

# %%
df_var_type = df_var.join(
    pd.Series(dt, name='type')
).assign(src='org')
df_var_type
# Out:
#                                                    Role         Type  \
# name
# Marital status                                  Feature      Integer
# Application mode                                Feature      Integer
# Application order                               Feature      Integer
# Course                                          Feature      Integer
# Daytime/evening attendance                      Feature      Integer
# Previous qualification                          Feature      Integer
# Previous qualification (grade)                  Feature   Continuous
# Nacionality                                     Feature      Integer
# Mother's qualification                          Feature      Integer
# Father's qualification                          Feature      Integer
# Mother's occupation                             Feature      Integer
# Father's occupation                             Feature      Integer
# Admission grade                                 Feature   Continuous
# Displaced                                       Feature      Integer
# Educational special needs                       Feature      Integer
# Debtor                                          Feature      Integer
# Tuition fees up to date                         Feature      Integer
# Gender                                          Feature      Integer
# Scholarship holder                              Feature      Integer
# Age at enrollment                               Feature      Integer
# International                                   Feature      Integer
# Curricular units 1st sem (credited)             Feature      Integer
# Curricular units 1st sem (enrolled)             Feature      Integer
# Curricular units 1st sem (evaluations)          Feature      Integer
# Curricular units 1st sem (approved)             Feature      Integer
# Curricular units 1st sem (grade)                Feature      Integer
# Curricular units 1st sem (without evaluations)  Feature      Integer
# Curricular units 2nd sem (credited)             Feature      Integer
# Curricular units 2nd sem (enrolled)             Feature      Integer
# Curricular units 2nd sem (evaluations)          Feature      Integer
# Curricular units 2nd sem (approved)             Feature      Integer
# Curricular units 2nd sem (grade)                Feature      Integer
# Curricular units 2nd sem (without evaluations)  Feature      Integer
# Unemployment rate                               Feature   Continuous
# Inflation rate                                  Feature   Continuous
# GDP                                             Feature   Continuous
# Target                                           Target  Categorical
#
#                                                     Demographic  \
# name
# Marital status                                   Marital status
# Application mode                                            NaN
# Application order                                           NaN
# Course                                                      NaN
# Daytime/evening attendance                                  NaN
# Previous qualification                          Education Level
# Previous qualification (grade)                              NaN
# Nacionality                                         Nationality
# Mother's qualification                          Education Level
# Father's qualification                          Education Level
# Mother's occupation                                  Occupation
# Father's occupation                                  Occupation
# Admission grade                                             NaN
# Displaced                                                   NaN
# Educational special needs                                   NaN
# Debtor                                                      NaN
# Tuition fees up to date                                     NaN
# Gender                                                   Gender
# Scholarship holder                                          NaN
# Age at enrollment                                           Age
# International                                               NaN
# Curricular units 1st sem (credited)                         NaN
# Curricular units 1st sem (enrolled)                         NaN
# Curricular units 1st sem (evaluations)                      NaN
# Curricular units 1st sem (approved)                         NaN
# Curricular units 1st sem (grade)                            NaN
# Curricular units 1st sem (without evaluations)              NaN
# Curricular units 2nd sem (credited)                         NaN
# Curricular units 2nd sem (enrolled)                         NaN
# Curricular units 2nd sem (evaluations)                      NaN
# Curricular units 2nd sem (approved)                         NaN
# Curricular units 2nd sem (grade)                            NaN
# Curricular units 2nd sem (without evaluations)              NaN
# Unemployment rate                                           NaN
# Inflation rate                                              NaN
# GDP                                                         NaN
# Target                                                      NaN
#
#                                                                                       Description  \
# name
# Marital status                                  1 – single 2 – married 3 – widower 4 – divorce...
# Application mode                                1 - 1st phase - general contingent 2 - Ordinan...
# Application order                               Application order (between 0 - first choice; a...
# Course                                          33 - Biofuel Production Technologies 171 - Ani...
# Daytime/evening attendance                                                1 – daytime 0 - evening
# Previous qualification                          1 - Secondary education 2 - Higher education -...
# Previous qualification (grade)                  Grade of previous qualification (between 0 and...
# Nacionality                                     1 - Portuguese; 2 - German; 6 - Spanish; 11 - ...
# Mother's qualification                          1 - Secondary Education - 12th Year of Schooli...
# Father's qualification                          1 - Secondary Education - 12th Year of Schooli...
# Mother's occupation                             0 - Student 1 - Representatives of the Legisla...
# Father's occupation                             0 - Student 1 - Representatives of the Legisla...
# Admission grade                                               Admission grade (between 0 and 200)
# Displaced                                                                          1 – yes 0 – no
# Educational special needs                                                          1 – yes 0 – no
# Debtor                                                                             1 – yes 0 – no
# Tuition fees up to date                                                            1 – yes 0 – no
# Gender                                                                        1 – male 0 – female
# Scholarship holder                                                                 1 – yes 0 – no
# Age at enrollment                                                    Age of studend at enrollment
# International                                                                      1 – yes 0 – no
# Curricular units 1st sem (credited)             Number of curricular units credited in the 1st...
# Curricular units 1st sem (enrolled)             Number of curricular units enrolled in the 1st...
# Curricular units 1st sem (evaluations)          Number of evaluations to curricular units in t...
# Curricular units 1st sem (approved)             Number of curricular units approved in the 1st...
# Curricular units 1st sem (grade)                Grade average in the 1st semester (between 0 a...
# Curricular units 1st sem (without evaluations)  Number of curricular units without evalutions ...
# Curricular units 2nd sem (credited)             Number of curricular units credited in the 2nd...
# Curricular units 2nd sem (enrolled)             Number of curricular units enrolled in the 2nd...
# Curricular units 2nd sem (evaluations)          Number of evaluations to curricular units in t...
# Curricular units 2nd sem (approved)             Number of curricular units approved in the 2nd...
# Curricular units 2nd sem (grade)                Grade average in the 2nd semester (between 0 a...
# Curricular units 2nd sem (without evaluations)  Number of curricular units without evalutions ...
# Unemployment rate                                                           Unemployment rate (%)
# Inflation rate                                                                 Inflation rate (%)
# GDP                                                                                           GDP
# Target                                          Target. The problem is formulated as a three c...
#
#                                                        type  src
# name
# Marital status                                         Int8  org
# Application mode                                       Int8  org
# Application order                                      Int8  org
# Course                                                Int16  org
# Daytime/evening attendance                             Int8  org
# Previous qualification                                 Int8  org
# Previous qualification (grade)                      Float32  org
# Nacionality                                            Int8  org
# Mother's qualification                                 Int8  org
# Father's qualification                                 Int8  org
# Mother's occupation                                   Int16  org
# Father's occupation                                   Int16  org
# Admission grade                                     Float32  org
# Displaced                                              Int8  org
# Educational special needs                              Int8  org
# Debtor                                                 Int8  org
# Tuition fees up to date                                Int8  org
# Gender                                                 Int8  org
# Scholarship holder                                     Int8  org
# Age at enrollment                                      Int8  org
# International                                          Int8  org
# Curricular units 1st sem (credited)                    Int8  org
# Curricular units 1st sem (enrolled)                    Int8  org
# Curricular units 1st sem (evaluations)                 Int8  org
# Curricular units 1st sem (approved)                    Int8  org
# Curricular units 1st sem (grade)                    Float32  org
# Curricular units 1st sem (without evaluations)         Int8  org
# Curricular units 2nd sem (credited)                    Int8  org
# Curricular units 2nd sem (enrolled)                    Int8  org
# Curricular units 2nd sem (evaluations)                 Int8  org
# Curricular units 2nd sem (approved)                    Int8  org
# Curricular units 2nd sem (grade)                    Float32  org
# Curricular units 2nd sem (without evaluations)         Int8  org
# Unemployment rate                                   Float32  org
# Inflation rate                                      Float32  org
# GDP                                                 Float32  org
# Target                                          Categorical  org

# %% [markdown]
# ## 변수 처리

# %%
dfl_train = pl.read_csv(files['train'], dtypes = dt)

# %%
def get_cat_values(var_name):
    return pd.Series(re.split("(?P<no>[0-9]+ - )", df_var.loc[var_name, "Description"])[1:])\
    .rename(index=lambda x: 'no' if x % 2 == 0 else 'desc').rename('var').reset_index().assign(
        item=lambda x: x.index // 2,
    ).pivot(index='item', columns='index', values='var')\
    .assign(
        no=lambda x: x['no'].str.slice(0, -3),
    )['no'].astype('int').values
cat_to_arrage = ['Application mode', 'Course', 'Previous qualification', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", "Nacionality"]

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()
dprocs = list()

filter_cat_val = lambda x: x.select(
    *[pl.when(pl.col(i).is_in(get_cat_values(i))).then(i).otherwise(-1) for i in cat_to_arrage]
)
desc = [('filter_{}'.format(i) , 'i: 설명에 등장하지 않은 변수를 -1로 치환합니다') for i in cat_to_arrage]
dprocs.append(
    partial(dproc.select_opr, select_proc=filter_cat_val, src='filtering_cat_val', desc=desc, df_feat=df_var_type)
)
dprocs.append(
    partial(dproc.apply_processor, processor=ord_enc, X_val=X_cat, 
            info_prov=partial(dproc.ord_prov, suffix='_o'), df_feat=df_var_type),
)

# %%
dfl_train, df_var_type = dproc.apply_procs(dfl_train, dprocs, df_feat=df_var_type)

# %% [markdown]
# ## 데이터 저장

# %%
dfl_train.to_pandas().set_index('id').to_pickle(files['train_pkl'])
del dfl_train

# %%
dfl_org = pl.read_csv(files['org'], dtypes = dt, separator=';')

# %%
dfl_org, _ = dproc.apply_procs(dfl_org, dprocs)
dfl_org.with_columns(**{'id': -pl.int_range(0, pl.len()) - 1}).to_pandas().set_index('id').to_pickle(files['org_pkl'])
del dfl_org

# %%
dfl_test = pl.read_csv(files['test'], dtypes = dt)

# %%
dfl_test, _ = dproc.apply_procs(dfl_test, dprocs)
dfl_test.to_pandas().set_index('id').to_pickle(files['test_pkl'])
del dfl_test

# %%
df_var_type.assign(
    var_type = lambda x: x['type'].astype(str)
).to_pickle(files['var_pkl'])
